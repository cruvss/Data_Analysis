# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("census.csv")

# %%
data.shape
# Out:
# (640, 25)

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %% [markdown]
# **how to hide index from data frame**

# %%
#data.style.hide(axis="index") throwing error something wrong with the data set

# %% [markdown]
# **set caption/heading for dataframe**

# %%
#df.style.set_caption("caption goes here")

# %% [markdown]
# **Show the records related with the districts - New Delhi , Lucknow , Jaipur**

# %%
data[data['District_name'].isin(['New Delhi','Lucknow','Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# **calculate total no of population sate wise**

# %%
data.groupby('State_name')['Population'].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# ...

# %%
data.groupby('State_name')[['Christians','Sikhs','Buddhists','Jains']].sum()
# Out:
#                              Christians     Sikhs  Buddhists    Jains
# State_name
# ANDAMAN AND NICOBAR ISLANDS       80984      1286        338       31
# ANDHRA PRADESH                  1129784     40244      36692    53849
# ARUNACHAL PRADESH                418732      3287     162815      771
# ASSAM                           1165867     20672      54993    25949
# BIHAR                            129247     23779      25453    18914
# CHANDIGARH                         8720    138329       1160     1960
# CHHATTISGARH                     490542     70036      70467    61510
# DADRA AND NAGAR HAVELI             5113       217        634     1186
# DAMAN AND DIU                      2820       172        217      287
# GOA                              366130      1473       1095     1109
# GUJARAT                          316178     58246      30483   579654
# HARYANA                           50353   1243752       7514    52613
# ...

# %%
#how many male workers in west bengal state?

# %%
data.head(1)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
#
# [1 rows x 25 columns]

# %%
data[data['State_name']=='WEST BENGAL'][['Male','Female']].sum()
# Out:
# Male      46809027
# Female    44467088
# dtype: int64

# %%
data.add_suffix("_2023").head(2) #this will add suffix in each column
# Out:
#                  State_name_2023 District_name_2023  Population_2023  \
# District_code
# 1              JAMMU AND KASHMIR            Kupwara           870354
# 2              JAMMU AND KASHMIR             Badgam           753745
#
#                Male_2023  Female_2023  Literate_2023  Workers_2023  \
# District_code
# 1                 474190       396164         439654        229064
# 2                 398041       355704         335649        214866
#
#                Male_Workers_2023  Female_Workers_2023  \
# District_code
# 1                         190899                38165
# 2                         162578                52288
#
#                Cultivator_Workers_2023  ...  Christians_2023  Sikhs_2023  \
# District_code                           ...
# 1                                34680  ...             1700        5600
# 2                                55299  ...             1489        5559
#
#                Buddhists_2023  Jains_2023  Secondary_Education_2023  \
# ...

# %%
data.set_index("District_code")
